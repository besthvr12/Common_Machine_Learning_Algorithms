# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
sns.heatmap(df.isnull())#To check if there is any null value or not in the data.

# %%
x=df['YearsExperience']
y=df['Salary']

# %%
plt.scatter(x,y)
plt.show()

# %%
#Now we calculate coefficient m and c of a linear regression(ypred=mx+c)

# %%
den=x.dot(x)-x.mean()*x.sum()

# %%
m=(x.dot(y)-y.mean()*x.sum())/den
c=(y.mean()*x.dot(x)-x.mean()*x.dot(y))/den

# %%
ypred=m*x+c

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,ypred,color='red')
plt.title('Salary vs Years Experienced')
plt.xlabel('Years Experienced ')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Now we will calculate R-Squared(To find how closed our data fitted to regression line):
a=y-ypred
b=y-y.mean()
rsquared=1-a.dot(a)/b.dot(b)
print(rsquared)
# Out:
# 0.9569566641435086

# %%
#Closer the value of r square to 1 more accurate the line fit our data.
